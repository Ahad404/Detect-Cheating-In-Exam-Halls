# %%
import cv2

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd "/kaggle/working/yolov5" && pip install -r requirements.txt

# %%
# !cd "/kaggle/working/yolov5" && python train.py \
--img 416 \
--batch-size 8 \
--data "/kaggle/input/cheating-detect/cheating detection.v7i.yolov5pytorch/data.yaml" \
--weights yolov5s.pt \
--epochs 100
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-09-05 04:27:27.684897: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757046447.708702     170 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757046447.715761     170 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
from IPython.display import FileLink
import shutil

# %%
shutil.make_archive("YOLO","zip","/kaggle/working")
# Out:
# '/kaggle/working/YOLO.zip'

# %%
FileLink(r"/kaggle/working/YOLO.zip")
# Out:
# /kaggle/working/YOLO.zip
